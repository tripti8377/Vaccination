# %%
import pandas as pd
import numpy as np
import os

# %%
X_train= pd.read_csv('training_set_features.csv')
X_test=pd.read_csv('test_set_features.csv')
Y_train=pd.read_csv('training_set_labels.csv')
Y_test=pd.read_csv('submission_format.csv')

# %%
X_train['education']=X_train['education'].fillna(X_train['education'].mode()[0])

# %%
edu=['< 12 Years', '12 Years', 'Some College', 'College Graduate']

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
enc = OrdinalEncoder(categories = [edu])

# %%
X_test['education']=X_test['education'].fillna(X_test['education'].mode()[0])

# %%
enc.fit_transform(X_test[['education']])
# Out:
# array([[3.],
#        [1.],
#        [3.],
#        ...,
#        [2.],
#        [2.],
#        [3.]])

# %%
X_test['education']=enc.fit_transform(X_test[['education']])

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
edu=['< 12 Years', '12 Years', 'Some College', 'College Graduate']
enc = OrdinalEncoder(categories = [edu])

# %%
enc.fit_transform(X_train[['education']])
# Out:
# array([[0.],
#        [1.],
#        [3.],
#        ...,
#        [2.],
#        [2.],
#        [2.]])

# %%
X_train['education']=enc.fit_transform(X_train[['education']])

# %%
X_train['income_poverty']=X_train['income_poverty'].fillna(X_train['income_poverty'].mode()[0])
X_test['income_poverty']=X_test['income_poverty'].fillna(X_test['income_poverty'].mode()[0])

# %%
X_train['income_poverty'].unique()
# Out:
# array(['Below Poverty', '<= $75,000, Above Poverty', '> $75,000'],
#       dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
income=['Below Poverty', '<= $75,000, Above Poverty','> $75,000']

# %%
enc = OrdinalEncoder(categories = [income])

# %%
X_train['income_poverty']=enc.fit_transform(X_train[['income_poverty']])

# %%
X_test['income_poverty']=enc.fit_transform(X_test[['income_poverty']])

# %%
X_train['age_group']=X_train['age_group'].fillna(X_train['age_group'].mode()[0])
X_test['age_group']=X_test['age_group'].fillna(X_test['age_group'].mode()[0])

# %%
age=['18 - 34 Years','35 - 44 Years','45 - 54 Years','55 - 64 Years', '65+ Years']

# %%
enc = OrdinalEncoder(categories = [age])

# %%
X_train['age_group']=enc.fit_transform(X_train[['age_group']])
X_test['age_group']=enc.fit_transform(X_test[['age_group']])

# %%
X_train['xyz_concern']=X_train['xyz_concern'].fillna(X_train['xyz_concern'].mode()[0])
X_test['xyz_concern']=X_test['xyz_concern'].fillna(X_test['xyz_concern'].mode()[0])

# %%
col=list(X_train.columns.values)

# %%
X_train[col]=X_train[col].fillna(X_train.mode().iloc[0])
X_test[col]=X_test[col].fillna(X_test.mode().iloc[0])

# %%
X_test=X_test.drop(['employment_industry','employment_occupation'], axis='columns')
X_train=X_train.drop(['employment_industry','employment_occupation'], axis='columns')

# %%
dummies=pd.get_dummies(X_train.race)
dum=pd.get_dummies(X_test.race)

# %%
X_train=pd.concat([X_train,dummies],axis='columns')

# %%
X_train=X_train.drop(['race','Other or Multiple'],axis=1)

# %%
X_test=pd.concat([X_test,dum],axis='columns')

# %%
X_test=X_test.drop(['race','Other or Multiple'],axis=1)

# %%
dummies=pd.get_dummies(X_train.sex)
dum=pd.get_dummies(X_test.sex)

# %%
X_train=pd.concat([X_train,dummies],axis='columns')

# %%
X_train=X_train.drop(['sex','Male'],axis=1)

# %%
X_test=pd.concat([X_test,dum],axis='columns')
X_test=X_test.drop(['sex','Male'],axis=1)

# %%
dummies=pd.get_dummies(X_train.marital_status)
dum=pd.get_dummies(X_test.marital_status)

# %%
X_train=pd.concat([X_train,dummies],axis='columns')
X_train
# Out:
#        respondent_id  xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 0                  0          1.0            0.0                        0.0
# 1                  1          3.0            2.0                        0.0
# 2                  2          1.0            1.0                        0.0
# 3                  3          1.0            1.0                        0.0
# 4                  4          2.0            1.0                        0.0
# ...              ...          ...            ...                        ...
# 26702          26702          2.0            0.0                        0.0
# 26703          26703          1.0            2.0                        0.0
# 26704          26704          2.0            2.0                        0.0
# 26705          26705          1.0            1.0                        0.0
# 26706          26706          0.0            0.0                        0.0
#
# ...

# %%
X_train=X_train.drop(['marital_status','Not Married'],axis=1)
X_test=pd.concat([X_test,dum],axis='columns')
X_test=X_test.drop(['marital_status','Not Married'],axis=1)

# %%
dummies=pd.get_dummies(X_train.rent_or_own)
dum=pd.get_dummies(X_test.rent_or_own)

# %%
X_train=pd.concat([X_train,dummies],axis='columns')

# %%
X_train=X_train.drop(['rent_or_own','Own'],axis=1)
X_test=pd.concat([X_test,dum],axis='columns')
X_test=X_test.drop(['rent_or_own','Own'],axis=1)

# %%
dummies=pd.get_dummies(X_train.employment_status)
dum=pd.get_dummies(X_test.employment_status)

# %%
X_train=pd.concat([X_train,dummies],axis='columns')
X_train
# Out:
#        respondent_id  xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 0                  0          1.0            0.0                        0.0
# 1                  1          3.0            2.0                        0.0
# 2                  2          1.0            1.0                        0.0
# 3                  3          1.0            1.0                        0.0
# 4                  4          2.0            1.0                        0.0
# ...              ...          ...            ...                        ...
# 26702          26702          2.0            0.0                        0.0
# 26703          26703          1.0            2.0                        0.0
# 26704          26704          2.0            2.0                        0.0
# 26705          26705          1.0            1.0                        0.0
# 26706          26706          0.0            0.0                        0.0
#
# ...

# %%
X_train=X_train.drop(['employment_status','Not in Labor Force'],axis=1)
X_test=pd.concat([X_test,dum],axis='columns')
X_test=X_test.drop(['employment_status','Not in Labor Force'],axis=1)

# %%
dummies=pd.get_dummies(X_train.hhs_geo_region)
dum=pd.get_dummies(X_test.hhs_geo_region)

# %%
X_train=pd.concat([X_train,dummies],axis='columns')

# %%
X_train=X_train.drop(['hhs_geo_region','qufhixun'],axis=1)
X_test=pd.concat([X_test,dum],axis='columns')
X_test=X_test.drop(['hhs_geo_region','qufhixun'],axis=1)

# %%
dummies=pd.get_dummies(X_train.census_msa)
dum=pd.get_dummies(X_test.census_msa)

# %%
X_train=pd.concat([X_train,dummies],axis='columns')

# %%
X_train=X_train.drop(['census_msa','Non-MSA'],axis=1)
X_test=pd.concat([X_test,dum],axis='columns')
X_test=X_test.drop(['census_msa','Non-MSA'],axis=1)

# %%
X_train.drop(['respondent_id'],axis=1)
X_test.drop(['respondent_id'],axis=1)
# Out:
#        xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 0              2.0            2.0                        0.0
# 1              1.0            1.0                        0.0
# 2              2.0            2.0                        0.0
# 3              1.0            1.0                        0.0
# 4              3.0            1.0                        1.0
# ...            ...            ...                        ...
# 26703          1.0            1.0                        0.0
# 26704          3.0            1.0                        0.0
# 26705          0.0            1.0                        0.0
# 26706          3.0            1.0                        0.0
# 26707          2.0            1.0                        0.0
#
#        behavioral_avoidance  behavioral_face_mask  behavioral_wash_hands  \
# 0                       1.0                   0.0                    1.0
# 1                       0.0                   0.0                    0.0
# ...

# %%
Y_train.drop(['respondent_id'],axis=1)
# Out:
#        xyz_vaccine  seasonal_vaccine
# 0                0                 0
# 1                0                 1
# 2                0                 0
# 3                0                 1
# 4                0                 0
# ...            ...               ...
# 26702            0                 0
# 26703            0                 0
# 26704            0                 1
# 26705            0                 0
# 26706            0                 0
#
# [26707 rows x 2 columns]

# %%
from sklearn.naive_bayes import BernoulliNB
from sklearn.multioutput import MultiOutputClassifier

# %%
base_model = BernoulliNB()
model = MultiOutputClassifier(base_model, n_jobs=-1)

# %%
model.fit(X_train, Y_train)
# Out:
# MultiOutputClassifier(estimator=BernoulliNB(), n_jobs=-1)

# %%
Y_prediction_ber= model.predict_proba(X_test)

# %%
xyz_ber= Y_prediction_ber[0][:, 1]
seasonal_ber=Y_prediction_ber[1][:, 1]

# %%
submission_ber = pd.DataFrame({
    'respondent_id': Y_test['respondent_id'],
    'h1n1_vaccine': xyz_ber,
    'seasonal_vaccine': seasonal_ber
})

# %%
submission_ber.to_csv('submission_ber.csv', index=False)
